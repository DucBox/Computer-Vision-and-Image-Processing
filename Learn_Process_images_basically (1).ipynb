# %%
from PIL import Image
import matplotlib.pyplot as plt
import numpy as np

# %%
image = Image.open('/content/TD.png')

# %%
plt.imshow(image)

# %%
image.size, image.format, image.mode, image.filename
# Out:
# ((1440, 1920), 'PNG', 'RGBA', '/content/TD.png')

# %%
from PIL import ImageOps

# %%
image_gray = ImageOps.grayscale(image)

# %%
plt.imshow(image_gray)

# %%
image_gray.mode, image_gray.size
# Out:
# ('L', (1440, 1920))

# %%
array = np.array(image)
array, array.shape
# Out:
# (array([[[199, 217, 227, 255],
#          [199, 217, 227, 255],
#          [199, 217, 227, 255],
#          ...,
#          [199, 221, 232, 255],
#          [200, 222, 233, 255],
#          [200, 222, 233, 255]],
#
#         [[199, 217, 227, 255],
#          [199, 217, 227, 255],
#          [199, 217, 227, 255],
#          ...,
#          [200, 222, 233, 255],
#          [200, 222, 233, 255],
#          [199, 221, 232, 255]],
#
#         [[199, 217, 227, 255],
#          [199, 217, 227, 255],
#          [199, 217, 227, 255],
#          ...,
#          [200, 222, 233, 255],
#          [199, 221, 232, 255],
#          [200, 222, 233, 255]],
#
#         ...,
#
#         [[184, 184, 182, 255],
#          [186, 186, 184, 255],
#          [187, 187, 185, 255],
#          ...,
#          [161, 159, 146, 255],
#          [167, 165, 152, 255],
#          [170, 168, 155, 255]],
#
#         [[178, 178, 176, 255],
#          [180, 180, 178, 255],
#          [182, 182, 180, 255],
#          ...,
# ...

# %%
import cv2

# %%
image = cv2.imread('/content/TD.png')

# %%
plt.imshow(image)

# %%
new_image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)

# %%
plt.imshow(image)

# %%
image_gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
plt.imshow(image_gray)

# %%
id(image)
A = image

# %%
print(id(A))
print(id(image))
# Out:
# 138035344692432
# 138035344692432

# %%
B = A.copy()
print(id(B))
# Out:
# 138035290495216

# %% [markdown]
# Flip Image by Using PIL

# %%
im_flip = ImageOps.flip(image)
plt.imshow(im_flip)

# %%
im_mirror = ImageOps.mirror(image)
plt.imshow(im_mirror)

# %% [markdown]
# Flip Image using OpenCV

# %%
im_flip_opencv = cv2.flip(image, 0)
plt.imshow(im_flip_opencv)

# %%
im_rotate_opencv = cv2.rotate(image, cv2.ROTATE_90_CLOCKWISE)
plt.imshow(im_rotate_opencv)
